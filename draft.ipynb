# %%
import pandas as pd

# %%
import pandas as pd

data = pd.read_excel(
    "bitacora_sintetica.xlsx",
    sheet_name= 1)

# %%
data.head()
# Out:
#        Fecha Hora  Arena No.4  Unnamed: 3   Unnamed: 4   Unnamed: 5  \
# 0        NaT  NaN  Malla No.4  Malla No.8  Malla No.16  Malla No.30
# 1 2025-01-01    1        99.7        87.1         65.1         39.2
# 2 2025-01-01    2        98.4        86.2         64.4         36.2
# 3 2025-01-01    3        98.5        90.2         62.9         39.7
# 4 2025-01-01    4        99.3        86.8         64.7         33.8
#
#     Unnamed: 6    Unnamed: 7        Unnamed: 8 Unnamed: 9  ...  Unnamed: 83  \
# 0  Malla No.50  Malla No.100  Módulo de Finura   %Humedad  ...  Malla No.10
# 1         12.4             4              2.75        3.1  ...         34.4
# 2         13.4           5.3               2.9          5  ...         38.4
# 3         11.9           3.2              2.67        4.7  ...         38.6
# 4         13.7           3.8              2.73        4.9  ...           31
#
#    Unnamed: 84   Unnamed: 85               Unnamed: 86  Unnamed: 87  \
# ...
